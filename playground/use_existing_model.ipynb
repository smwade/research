# %%
from keras.applications.resnet50 import ResNet50
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import tensorflow as tf

# %%
resnet = ResNet50(weights='imagenet', include_top=True)

# %%
vgg = VGG16(weights='imagenet', include_top=True)

# %%
img = image.load_img('./images/elephant.jpg', target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x130735E18>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = vgg.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# ('Predicted:', [(u'n02504458', u'African_elephant', 0.93287086), (u'n01871265', u'tusker', 0.06458699), (u'n02504013', u'Indian_elephant', 0.0025169083)])

# %%
preds = resnet.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ('Predicted:', [(u'n02504458', u'African_elephant', 0.94370991), (u'n01871265', u'tusker', 0.042936668), (u'n02504013', u'Indian_elephant', 0.011697253)])
